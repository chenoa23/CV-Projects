# %% [markdown]
# <a href="https://colab.research.google.com/github/chenoa23/CV-Projects/blob/main/Beautiful%20Soup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping using beautifulsoup
#
# Chenoa Nussberger

# %% [markdown]
# ### Beautifulsoup
#
# BeautifulSoup, is an open-source tool and used for web scraping

# %% [markdown]
# Beautiful Soup is a python package and as the name suggests, parses the unwanted data and helps to organize and format the messy web data by fixing bad HTML and present to us in an easily-traversible XML structures

# %% [markdown]
# #### First, let us download the pakage

# %% [markdown]
# #### Let us now import all the required packages

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.12.2)

# %% [markdown]
# ###  Importing required libraries/ packages
# First, we import the packages that are required:
# - The `requests` package allows our python script to communicate with websites and to 'request' information from those sites.
# - The beautiful soup package, also known as `bs4` takes the raw information from the websites and provides helpful functions to extract information.

# %%
import numpy as np
import pandas as pd

# %%
import requests
import bs4
from urllib.request import urlopen
import shutil
import os

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# #### Now that we have the required libraries, let us try something
# ##### Let us try to get the title of  wikipedia website

# %%
base_url = 'https://en.wikipedia.org/wiki/Jupiter'
r = requests.get(base_url)
r
soup = bs4.BeautifulSoup(r.text,'html5lib')
print(soup.title)
# Out:
# <title>Jupiter - Wikipedia</title>

# %% [markdown]
# ### Task: Try changing the base_url from 'https://en.wikipedia.org/wiki/Jupiter' to 'https://en.wikipedia.org/wiki/Jus21'.
# What did the response code become?
#
# These codes can help in troubleshooting and solving connection problems, but now, we just need to know that a response of 200 means that your GET request was successful!
#
# <em> In case the link is not working for you, you may get a `<Response [404]>` from the code above </em>
#
# ### Now change the base url back to 'https://en.wikipedia.org/wiki/Jupiter' from 'https://en.wikipedia.org/wiki/Jus21' to continue with the rest of the notebook.
#
# Connection establised! We have access!

# %% [markdown]
# ### 1.1.3 Using beautifulsoup to get data from websites
#
# Now we can use `bs4` to read the outputs from our request.
#
# Beautiful Soup is a Python library for getting data out of HTML, XML, and other markup languages.
# *Note: This section of the Jupyter Notebook is written in 'markup' format.
#
# Much like our browser, bs4 is able to understand HTML and to read the < tags >;

# %% [markdown]
# See the code below!

# %%
#`r.text` contains the raw HTML returned when we made our GET request earlier.
#`'html5lib'` tells BeautifulSoup that it is reading HTML information.
soup = bs4.BeautifulSoup(r.text,'html5lib')

# %% [markdown]
# Essentially, we are taking the raw response from the GET request, and asking BeautifulSoup to read and understand the response, and store all of this as your variable `soup`!

# %% [markdown]
# ### Using beautifulsoup to search for specific tags
#
# This is where it gets interesting. BeautifulSoup can be used to search for specific tags.
#
# Let's use beautifulsoup to look for all the headings within the Wikipedia website!

# %% [markdown]
# headers = []
# for url in soup.findAll("h3"):
#     headers.append(url.text)
#     print(url.text)

# %% [markdown]
# In this code snippet, we find all `<h3>` tags. We then loop through each tag found and extract the text by using the .
#
# *Note: The `<h3>` tag defines a [header](https://www.w3docs.com/learn-html/html-header-tag.html), which defines the heading for the text to follow. To differentiate `<h3>` tags appearing in different locations, they can be 'named' with a `class=tag-name`. In this exercise, we are searching for headers `<h3>` without any classes.

# %% [markdown]
# #### Let us try to extract all URLs from the intel website

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Jupiter
# /w/index.php?title=Special:UserLogin&returnto=Jupiter
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=Jupiter
# /w/index.php?title=Special:UserLogin&returnto=Jupiter
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Name_and_symbol
# #Formation_and_migration
# #Physical_characteristics
# #Composition
# #Size_and_mass
# #Internal_structure
# #Atmosphere
# #Cloud_layers
# #Great_Red_Spot_and_other_vortices
# #Magnetosphere
# #Planetary_rings
# #Orbit_and_rotation
# #Observation
# #History
# #Pre-telescopic_research
# #Ground-based_telescope_research
# #Radiotelescope_research
# #Exploration
# #Flyby_missions
# #Galileo_mission
# #Juno_mission
# #Cancelled_missions_and_future_plans
# #Moons
# #Galilean_moons
# #Classification
# #Interaction_with_the_Solar_System
# #Impacts
# #In_culture
# #See_also
# #Notes
# #References
# #Further_reading
# #External_links
# https://af.wikipedia.org/wiki/Jupiter
# https://als.wikipedia.org/wiki/Jupiter_(Planet)
# https://am.wikipedia.org/wiki/%E1%8C%81%E1%8D%92%E1%89%B0%E1%88%AD
# https://smn.wikipedia.org/wiki/Jupiter
# https://anp.wikipedia.org/wiki/%E0%A4%AC%E0%A5%8D%E0%A4%B0%E0%A5%87%E0%A4%B8%E0%A5%8D%E0%A4%AA%E0%A4%A4%E0%A4%BF_%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%B9
# https://ang.wikipedia.org/wiki/%C3%9Eunor_(tungol)
# https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D9%85%D8%B4%D8%AA%D8%B1%D9%8A
# https://an.wikipedia.org/wiki/Chupiter_(planeta)
# https://hyw.wikipedia.org/wiki/%D4%BC%D5%B8%D6%82%D5%BD%D5%B6%D5%A9%D5%A1%D5%A3
# https://roa-rup.wikipedia.org/wiki/Jupiter
# https://frp.wikipedia.org/wiki/Jupit%C3%A8r_(plan%C3%A8ta)
# https://as.wikipedia.org/wiki/%E0%A6%AC%E0%A7%83%E0%A6%B9%E0%A6%B8%E0%A7%8D%E0%A6%AA%E0%A6%A4%E0%A6%BF_%E0%A6%97%E0%A7%8D%E0%A7%B0%E0%A6%B9
# https://ast.wikipedia.org/wiki/X%C3%BApiter_(planeta)
# https://awa.wikipedia.org/wiki/%E0%A4%AC%E0%A5%83%E0%A4%B9%E0%A4%B8%E0%A5%8D%E0%A4%AA%E0%A4%A4%E0%A4%BF_%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%B9
# https://gn.wikipedia.org/wiki/H%C3%BApiter
# https://av.wikipedia.org/wiki/%D0%AE%D0%BF%D0%B8%D1%82%D0%B5%D1%80
# https://az.wikipedia.org/wiki/Yupiter_(planet)
# https://azb.wikipedia.org/wiki/%D9%85%D9%88%D8%B4%D8%AA%D8%B1%DB%8C
# https://ban.wikipedia.org/wiki/Jupiter
# https://bn.wikipedia.org/wiki/%E0%A6%AC%E0%A7%83%E0%A6%B9%E0%A6%B8%E0%A7%8D%E0%A6%AA%E0%A6%A4%E0%A6%BF_%E0%A6%97%E0%A7%8D%E0%A6%B0%E0%A6%B9
# https://bjn.wikipedia.org/wiki/Yupiter
# https://zh-min-nan.wikipedia.org/wiki/Bo%CC%8Dk-chhe%E2%81%BF
# https://ba.wikipedia.org/wiki/%D0%AE%D0%BF%D0%B8%D1%82%D0%B5%D1%80
# https://be.wikipedia.org/wiki/%D0%AE%D0%BF%D1%96%D1%82%D1%8D%D1%80_(%D0%BF%D0%BB%D0%B0%D0%BD%D0%B5%D1%82%D0%B0)
# https://be-tarask.wikipedia.org/wiki/%D0%AE%D0%BF%D1%96%D1%82%D1%8D%D1%80
# https://bh.wikipedia.org/wiki/%E0%A4%AC%E0%A5%83%E0%A4%B9%E0%A4%B8%E0%A5%8D%E0%A4%AA%E0%A4%A4%E0%A4%BF_%E0%A4%97%E0%A5%8D%E0%A4%B0%E0%A4%B9
# https://bcl.wikipedia.org/wiki/Hupiter
# https://bg.wikipedia.org/wiki/%D0%AE%D0%BF%D0%B8%D1%82%D0%B5%D1%
# /wiki/Planet_symbols
# /wiki/File:Jupiter_symbol_(bold).svg
# /wiki/Osculating_orbit
# #cite_note-fact-3
# /wiki/Epoch_(astronomy)
# /wiki/J2000
# /wiki/Perihelion_and_aphelion
# /wiki/Astronomical_unit
# /wiki/Kilometre
# /wiki/Perihelion_and_aphelion
# /wiki/Semi-major_and_semi-minor_axes
# /wiki/Orbital_eccentricity
# /wiki/Orbital_period
# /wiki/Julian_year_(astronomy)
# /wiki/Solar_day
# #cite_note-planet_years-4
# /wiki/Orbital_period
# /wiki/Orbital_speed
# /wiki/Mean_anomaly#Mean_anomaly_at_epoch
# #cite_note-VSOP87-5
# /wiki/Orbital_inclination
# /wiki/Ecliptic
# #cite_note-VSOP87-5
# /wiki/Sun
# /wiki/Equator
# #cite_note-VSOP87-5
# /wiki/Invariable_plane
# #cite_note-Souami_Souchay_2012-6
# /wiki/Longitude_of_the_ascending_node
# /wiki/Apsis
# #cite_note-horizons-perihelion-7
# /wiki/Argument_of_periapsis
# #cite_note-VSOP87-5
# /wiki/Natural_satellite
# /wiki/Moons_of_Jupiter
# https://en.wikipedia.org/w/index.php?title=Jupiter&action=edit
# #cite_note-SheppardMoons-8
# #cite_note-fact-3
# #cite_note-Seidelmann_Archinal_A'hearn_et_al._2007-9
# #cite_note-PS15-10
# /wiki/Mean_radius_(astronomy)
# #cite_note-1bar-11
# /wiki/Equator
# #cite_note-1bar-11
# /wiki/Equatorial_radius
# /wiki/Solar_radius
# /wiki/Geographical_pole
# #cite_note-1bar-11
# /wiki/Flattening
# /wiki/Spheroid#Surface_area
# /wiki/Surface_area_of_earth
# /wiki/Volume
# #cite_note-1bar-11
# /wiki/Volume_of_Earth
# /wiki/Mass
# /wiki/Earth_mass
# /wiki/Solar_mass
# #cite_note-ssd-constants-12
# /wiki/Density
# #cite_note-1bar_b-13
# /wiki/Surface_gravity
# /wiki/Metre_per_second_squared
# /wiki/Standard_gravity
# #cite_note-1bar-11
# #cite_note-nasafact-14
# /wiki/Moment_of_inertia_factor
# #cite_note-Ni2018-15
# /wiki/Escape_velocity
# #cite_note-1bar-11
# /wiki/Synodic_rotation_period
# #cite_note-planet_years-4
# /wiki/Sidereal_rotation_period
# /wiki/Axial_tilt
# /wiki/Right_ascension
# #cite_note-iau2015-16
# /wiki/Declination
# #cite_note-iau2015-16
# /wiki/Albedo
# /wiki/Bond_albedo
# #cite_note-Li_et_al-17
# /wiki/Geometric_albedo
# #cite_note-Mallama_et_al-18
# /wiki/Temperature
# /wiki/Effective_temperature
# /wiki/Temperature
# /wiki/Bar_(unit)
# /wiki/Kelvin
# /wiki/Apparent_magnitude
# #cite_note-Mallama_and_Hilton-19
# #cite_note-Mallama_and_Hilton-19
# /wiki/Absolute_magnitude#Solar_System_bodies_(H)
# #cite_note-IMCCE-20
# /wiki/Angular_diameter
# #cite_note-fact-3
# /wiki/Atmospheric_pressure
# #cite_note-21
# /wiki/Scale_height
# /wiki/Atmospheric_chemistry#Atmospheric_composition
# /wiki/Hydrogen
# /wiki/Helium
# /wiki/Methane
# /wiki/Ammonia
# /wiki/Hydrogen_deuteride
# /wiki/Ethane
# /wiki/Water
# /wiki/Planet
# /wiki/Sun
# /wiki/List_of_Solar_System_objects_by_size
# /wiki/Gas_giant
# /wiki/Jupiter_mass
# /wiki/Solar_System
# /wiki/Earth
# /wiki/Astronomical_unit
# /wiki/Gigametre
# /wiki/Orbital_period
# /wiki/Julian_year_(astronomy)
# /wiki/List_of_brightest_natural_objects_in_the_sky
# /wiki/Night_sky
# /wiki/Moon
# /wiki/Venus
# /wiki/Prehistoric_times
# /wiki/Jupiter_(god)
# /wiki/Ancient_Roman_religion
# /wiki/Jupiter%27s_atmosphere
# /wiki/Hydrogen
# /wiki/Helium
# /wiki/Carbon
# /wiki/Oxygen
# /wiki/Sulfur
# /wiki/Neon
# /wiki/Ammonia
# /wiki/Water_vapour
# /wiki/Phosphine
# /wiki/Hydrogen_sulfide
# /wiki/Hydrocarbon
# /wiki/Saturn
# /wiki/Metallic_hydrogen
# /wiki/Oblate_spheroid
# #cite_note-22
# /wiki/Great_Red_Spot
# /wiki/Magnetic_field
# /wiki/Eddy_current
# /wiki/Solar_wind
# /wiki/Magnetosphere
# /wiki/Planetary_ring
# /wiki/Voyager_1
# /wiki/Galileo_orbiter
# /wiki/Rings_of_Jupiter
# /wiki/Torus
# /wiki/Moons_of_Jupiter
# /wiki/Galilean_moons
# /wiki/Io_(moon)
# /wiki/Europa_(moon)
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Galileo_Galilei
# /wiki/Mercury_(planet)
# /wiki/List_of_missions_to_the_outer_planets
# /wiki/Robotic_spacecraft
# /wiki/Flyby_(spaceflight)
# /wiki/Pantheon_(religion)
# /wiki/Zeus
# /wiki/Jupiter_(god)
# #cite_note-23
# /wiki/International_Astronomical_Union
# #cite_note-24
# /wiki/Planetary_symbol
# /wiki/File:Jupiter_symbol_(fixed_width).svg
# /wiki/Zeta
# /wiki/Scribal_abbreviation#Forms
# #cite_note-jones-1999-25
# #cite_note-26
# /wiki/Genitive_case
# /wiki/Iuppiter
# #cite_note-27
# /wiki/Adjective
# /wiki/Middle_Ages
# /wiki/Jupiter_(astrology)
# #cite_note-28
# https://en.wiktionary.org/wiki/zenography
# #cite_note-29
# /wiki/Grand_tack_hypothesis
# /wiki/Formation_and_evolution_of_the_Solar_System
# #cite_note-Kruijer_et_al_2017-30
# /wiki/Frost_line_(astrophysics)
# /wiki/Volatile_(astrogeology)
# #cite_note-Bosman_et_al_2019-31
# /wiki/Primary_atmosphere
# #cite_note-dangelo2021-32
# #cite_note-Kruijer_et_al_2017-30
# #cite_note-Kruijer_et_al_2017-30
# #cite_note-Kruijer_et_al_2017-30
# #cite_note-dangelo2021-32
# /wiki/Solar_System
# /wiki/Star_system
# /wiki/Formation_and_evolution_of_the_Solar_System
# /wiki/Protostar
# /wiki/Brown_dwarf
# #cite_note-33
# #cite_note-DROBYSHEVSKI_1974_pp._35–36-34
# /wiki/Grand_tack_hypothesis
# /wiki/Astronomical_unit
# /wiki/Kilometre
# /wiki/Mile
# /wiki/Accretion_(astrophysics)
# /wiki/Orbital_resonance
# /wiki/Saturn
# #cite_note-Bosman_et_al_2019-31
# #cite_note-Walsh_etal_2011-35
# /wiki/Super-Earth
# #cite_note-tack-36
# /wiki/Mean_motion_resonance
# #cite_note-37
# #cite_note-tack-36
# #cite_note-Walsh_etal_2011-35
# #cite_note-38
# #cite_note-39
# #cite_note-zube_2019-40
# /wiki/Solar_nebula
# #cite_note-dangelo_marzari_2012-41
# #cite_note-dangelo2021-32
# #cite_note-Pirani_et_al_2019-42
# #cite_note-Pirani_accompanying_article-43
# /wiki/Nice_model
# /wiki/Kuiper_belt
# /wiki/Late_Heavy_Bombardment
# #cite_note-Levison2008-44
# /wiki/Jumping-Jupiter_scenario
# /wiki/Fifth_Giant
# #cite_note-45
# /wiki/Molecular_nitrogen
# #cite_note-n2_snowline_2019-46
# #cite_note-47
# #cite_note-Pirani_et_al_2019-42
# #cite_note-Pirani_accompanying_article-43
# #cite_note-Pirani_et_al_2019-42
# /wiki/Gas_giant
# /wiki/Equator
# #cite_note-fact-3
# #cite_note-48
# #cite_note-50
# /wiki/Terrestrial_planet
# #cite_note-51
# #cite_note-52
# /wiki/Atmosphere_of_Jupiter
# #cite_note-53
# /wiki/Carbon
# /wiki/Oxygen
# /wiki/Sulfur
# /wiki/Neon
# #cite_note-54
# /wiki/Ammonia
# /wiki/Water_vapour
# /wiki/Phosphine
# /wiki/Hydrogen_sulfide
# /wiki/Hydrocarbons
# /wiki/Methane
# /wiki/Ethane
# /wiki/Benzene
# #cite_note-55
# /wiki/Crystal
# #cite_note-56
# #cite_note-voyager-57
# #cite_note-cassini-58
# /wiki/Solar_nebula
# #cite_note-59
# #cite_note-60
# /wiki/Precipitation_(meteorology)
# #cite_note-galileo_ms-61
# #cite_note-Juno-62
# /wiki/Spectroscopy
# /wiki/Saturn
# /wiki/Uranus
# /wiki/Neptune
# /wiki/Abundance_of_the_chemical_elements
# #cite_note-63
# /wiki/Ice_giants
# #cite_note-icegiantatmospheres-64
# /wiki/Jupiter_mass
# /wiki/File:Jupiter_size.png
# /wiki/Earth_radius
# #cite_note-fact-3
# /wiki/Barycentre
# /wiki/Photosphere
# /wiki/Solar_radius
# #cite_note-65
# #cite_note-burgess-66
# /wiki/Solar_radius
# #cite_note-shu82-67
# /wiki/Solar_mass
# #cite_note-davis_turekian05-68
# /wiki/Jupiter_mass
# /wiki/Extrasolar_planet
# /wiki/Brown_dwarf
# /wiki/HD_209458_b
# /wiki/Gliese_229_b
# #cite_note-69
# #cite_note-Feng2022-70
# /wiki/Radius
# #cite_note-Seager2007-71
# #cite_note-HTUW-72
# /wiki/Stellar_ignition
# #cite_note-tristan286-73
# /wiki/Hydrogen_fusion
# /wiki/Star
# #cite_note-74
# /wiki/Red_dwarf
# #cite_note-75
# /wiki/Kelvin%E2%80%93Helmholtz_mechanism
# #cite_note-elkins-tanton-76
# #cite_note-77
# #cite_note-78
# #cite_note-guillot04-79
# #cite_note-80
# /wiki/File:Jupiter_diagram.svg
# /wiki/Planetary_core
# /wiki/Metallic_hydrogen
# #cite_note-81
# /wiki/Molecular_hydrogen
# #cite_note-guillot04-79
# /wiki/Protoplanetary_disk
# /wiki/Juno_(spacecraft)
# #cite_note-82
# #cite_note-dilute-83
# #cite_note-NYT-20160705-84
# #cite_note-stevenson2022-85
# #cite_note-dilute-83
# #cite_note-nature2019_2-86
# /wiki/Critical_pressure
# /wiki/Pascal_(unit)
# /wiki/Critical_temperature
# /wiki/Kelvin
# /wiki/Celsius
# /wiki/Fahrenheit
# #cite_note-87
# /wiki/Supercritical_fluid
# #cite_note-elkins-tanton-76
# #cite_note-88
# #cite_note-89
# #cite_note-90
# #cite_note-lang03-91
# #cite_note-galileo_ms-61
# #cite_note-92
# #cite_note-93
# /wiki/Extraterrestrial_diamonds
# #cite_note-SC-20131009-94
# #cite_note-WP-20170825-95
# #cite_note-Juno-62
# /wiki/Bar_(unit)
# /wiki/Pascal_(unit)
# #cite_note-Guillot_et_al_2004-96
# /wiki/Atmosphere_of_Jupiter
# /wiki/File:790106-0203_Voyager_58M_to_31M_reduced.gif
# /wiki/Voyager_1
# #cite_note-Atreya2003-97
# #cite_note-Guillot_et_al_2004-96
# /wiki/Ammonium_hydrosulfide
# #cite_note-98
# /wiki/Tropopause
# /wiki/Atmospheric_circulation
# /wiki/Turbulence
# /wiki/Jet_stream#Other_planets
# #cite_note-99
# #cite_note-burgess-66
# /wiki/File:Map_of_Jupiter.jpg
# /wiki/File:PIA21641-Jupiter-SouthernStorms-JunoCam-20170525.jpg
# /wiki/Water_(properties)
# /wiki/Lightning
# #cite_note-100
# #cite_note-101
# #cite_note-102
# #cite_note-103
# #cite_note-104
# /wiki/Upper-atmospheric_lightning
# #cite_note-105
# #cite_note-106
# #cite_note-elkins-tanton-76
# #cite_note-107
# /wiki/Chromophore
# /wiki/Convection_cell
# #cite_note-worldbook-108
# /wiki/Axial_tilt
# /wiki/Solar_radiation
# /wiki/Convection
# #cite_note-burgess-66
# /wiki/File:PIA21775.jpg
# /wiki/Juno_spacecraft
# /wiki/Barrel_distortion
# /wiki/Great_Red_Spot
# #cite_note-NYT-20171213-109
# /wiki/Anticyclone
# #cite_note-110
# #cite_note-kyrala26-111
# #cite_note-112
# /wiki/Hubble_Space_Telescope
# #cite_note-113
# #cite_note-114
# /wiki/Telescope
# /wiki/Aperture
# #cite_note-115
# /wiki/Period_(physics)
# #cite_note-116
# #cite_note-117
# /wiki/Ammonia
# /wiki/Acetylene
# #cite_note-118
# #cite_note-sp.news20151125-119
# /wiki/Mathematical_model
# #cite_note-120
# https://en.wikipedia.org/w/index.php?title=Jupiter&action=edit
# #cite_note-Simon2015-121
# #cite_note-sp.news20151125-119
# #cite_note-122
# #cite_note-Adriani_et_al_2018-123
# #cite_note-124
# /wiki/File:Oval_BA_(Hubble).jpg
# /wiki/Oval_BA
# #cite_note-125
# #cite_note-126
# /wiki/Jupiter%27s_North_Pole
# /wiki/Vortex
# /wiki/Metastability
# /wiki/Vorticity
# #cite_note-Stallard_et_Al.,_2017-127
# /wiki/Magnetosphere_of_Jupiter
# /wiki/File:PIA23465-PlanetJupiter-Aurorae-20191001.gif
# /wiki/Aurora
# /wiki/Jupiter%27s_North_Pole
# /wiki/Jupiter%27s_South_Pole
# /wiki/File:Hubble_Captures_Vivid_Auroras_in_Jupiter%27s_Atmosphere.jpg
# /wiki/Aurora
# /wiki/File:PIA21033_Juno%27s_View_of_Jupiter%27s_Southern_Lights.jpg
# /wiki/Infrared
# /wiki/Jovian_Infrared_Auroral_Mapper
# /wiki/Roentgen_equivalent_man
# #cite_note-ringwald-128
# #cite_note-ringwald-128
# #cite_note-ringwald-128
# #cite_note-ringwald-128
# /wiki/Magnetic_field
# #cite_note-worldbook-108
# /wiki/Magnetic_dipole_moment
# /wiki/Gauss_(unit)
# /wiki/Tesla_(unit)
# #cite_note-129
# /wiki/Eddy_current
# /wiki/Solar_wind
# /wiki/Bow_shock
# /wiki/Magnetopause
# /wiki/Magnetosheath
# /wiki/Lee_side
# #cite_note-elkins-tanton-76
# /wiki/Io_(moon)
# /wiki/Sulfur_dioxide
# /wiki/Torus
# /wiki/Ionization
# /wiki/Magnetosphere
# /wiki/Ion
# /wiki/Plasma_sheet
# /wiki/Hertz
# /wiki/Shortwave_radio_receiver
# #cite_note-130
# #cite_note-131
# /wiki/Alfv%C3%A9n_wave
# /wiki/Cyclotron
# /wiki/Astrophysical_maser
# /wiki/Radio_wave
# #cite_note-132
# /wiki/File:Jupiter_Showcases_Auroras,_Hazes_(NIRCam_Widefield_View)_(jupiter-auroras2).jpeg
# /wiki/Rings_of_Jupiter
# /wiki/Planetary_ring
# /wiki/Torus
# #cite_note-133
# #cite_note-elkins-tanton-76
# /wiki/Adrastea_(moon)
# /wiki/Metis_(moon)
# #cite_note-Burns1999-134
# /wiki/Thebe_(moon)
# /wiki/Amalthea_(moon)
# #cite_note-Burns1999-134
# #cite_note-135
# /wiki/File:Jupiter_rotation_over_3_hours_with_11_inch_telescope.gif
# /wiki/Barycentre
# #cite_note-136
# #cite_note-Jupiter-COM-20160730-137
# /wiki/Orbital_resonance
# #cite_note-138
# /wiki/Orbital_plane
# /wiki/Orbital_inclination
# /wiki/Orbital_eccentricity
# /wiki/Perihelion
# /wiki/Aphelion
# #cite_note-fact-3
# /wiki/Exoplanet
# #cite_note-139
# /wiki/Axial_tilt
# #cite_note-140
# /wiki/Period_of_revolution
# /wiki/Coordinate_axis
# /wiki/Equatorial_bulge
# /wiki/Differential_rotation
# #cite_note-Ridpath1998-141
# /wiki/Equator
# /wiki/Geographic_pole
# #cite_note-lang03-91
# #cite_note-fact-3
# #cite_note-Hide1981-142
# /wiki/Radio_astronomer
# #cite_note-143
# /wiki/File:Jupiter-and-its-moons-amateur.jpg
# /wiki/List_of_brightest_natural_objects_in_the_sky
# /wiki/Moon
# /wiki/Venus
# #cite_note-worldbook-108
# /wiki/Mars#Viewing_from_Earth
# /wiki/Opposition_(astronomy)
# /wiki/Conjunction_(astronomy_and_astrology)
# #cite_note-Mallama_and_Hilton-19
# /wiki/Apparent_magnitude
# #cite_note-Mallama_and_Hilton-19
# /wiki/Angular_diameter
# /wiki/Arc_second
# #cite_note-fact-3
# /wiki/Apsis
# #cite_note-144
# /wiki/Apparent_retrograde_motion
# #cite_note-145
# /wiki/Phase_angle_(astronomy)
# #cite_note-146
# /wiki/Galilean_moons
# /wiki/Atmosphere_of_Jupiter
# #cite_note-147
# #cite_note-148
# /wiki/File:Almagest-planets.svg
# /wiki/Almagest
# /wiki/Babylonian_astronomers
# #cite_note-149
# /wiki/Earthly_branches
# /wiki/Chinese_language
# /wiki/Simplified_characters
# /wiki/Chinese_zodiac
# #cite_note-Homer-150
# /wiki/Tai_Sui
# /wiki/Chinese_gods
# /wiki/Taoist
# /wiki/Chinese_folk_religion
# /wiki/Xi_Zezong
# /wiki/Gan_De
# /wiki/Chinese_astronomy
# #cite_note-151
# #cite_note-152
# /wiki/Moons_of_Jupiter
# #cite_note-153
# #cite_note-154
# /wiki/Trapezoidal_rule
# /wiki/Babylon
# /wiki/Ecliptic
# #cite_note-155
# /wiki/Almagest
# /wiki/Claudius_Ptolemaeus
# /wiki/Geocentric
# /wiki/Deferent
# /wiki/Epicycle
# #cite_note-156
# /wiki/File:Medicean_Stars.png
# /wiki/Sidereus_Nuncius
# /wiki/Galileo_Galilei
# /wiki/Galilean_moons
# /wiki/Simon_Marius
# #cite_note-157
# /wiki/Heliocentrism
# /wiki/Nicolaus_Copernicus
# /wiki/Inquisition
# #cite_note-158
# #cite_note-159
# /wiki/Giovanni_Domenico_Cassini
# #cite_note-cassini1-160
# #cite_note-161
# /wiki/Robert_Hooke
# /wiki/Samuel_Heinrich_Schwabe
# #cite_note-162
# #cite_note-163
# #cite_note-164
# /wiki/Giovanni_Alfonso_Borelli
# /wiki/Ole_R%C3%B8mer
# #cite_note-cassini-58
# /wiki/Speed_of_light
# #cite_note-165
# #cite_note-166
# /wiki/E._E._Barnard
# /wiki/Lick_Observatory
# /wiki/Amalthea_(moon)
# #cite_note-167
# #cite_note-168
# /wiki/Voyager_1
# #cite_note-169
# /wiki/Rupert_Wildt
# /wiki/Absorption_bands
# #cite_note-170
# /wiki/Oval_BA
# #cite_note-171
# /wiki/Kenneth_Franklin
# #cite_note-elkins-tanton-76
# #cite_note-172
# #cite_note-173
# /wiki/Frank_Drake
# #cite_note-elkins-tanton-76
# /wiki/Cyclotron_radiation
# #cite_note-174
# /wiki/Thermal_radiation
# #cite_note-elkins-tanton-76
# /wiki/Exploration_of_Jupiter
# /wiki/Spacecraft
# /wiki/Pioneer_10
# #cite_note-175
# #cite_note-176
# /wiki/Delta-v
# /wiki/Hohmann_transfer_orbit
# /wiki/Low_Earth_orbit
# #cite_note-177
# #cite_note-178
# /wiki/Gravitational_slingshot
# /wiki/Gravitational_slingshot
# #cite_note-delta-v-179
# /wiki/Pioneer_10
# /wiki/Pioneer_11
# /wiki/Voyager_1
# /wiki/Voyager_2
# /wiki/Ulysses_probe
# #cite_note-ulysses-180
# #cite_note-ulysses-180
# /wiki/Cassini%E2%80%93Huygens
# /wiki/New_Horizons
# /wiki/Pioneer_program
# /wiki/Moons_of_Jupiter
# /wiki/Radio_occultations
# #cite_note-burgess-66
# #cite_note-cosmology_101-181
# /wiki/Voyager_program
# /wiki/Galilean_moons
# /wiki/Terminator_(solar)
# #cite_note-burgess-66
# #cite_note-voyager1-182
# /wiki/Ulysses_(spacecraft)
# /wiki/Polar_orbit
# #cite_note-ulysses-180
# #cite_note-183
# /wiki/New_Horizons
# /wiki/Pluto
# #cite_note-184
# #cite_note-185
# /wiki/Galileo_(spacecraft)
# /wiki/File:Galileo_Preparations_-_GPN-2000-000672.jpg
# /wiki/Galileo_(spacecraft)
# #cite_note-HTUW-72
# /wiki/Amalthea_(moon)
# /wiki/Comet_Shoemaker%E2%80%93Levy_9
# #cite_note-galileo-186
# /wiki/Galileo_(spacecraft)#Galileo_entry_probe
# #cite_note-HTUW-72
# #cite_note-HTUW-72
# #cite_note-187
# /wiki/NASA
# /wiki/Life_on_Europa
# #cite_note-galileo-186
# #cite_note-HTUW-72
# #cite_note-HTUW-72
# /wiki/Juno_(spacecraft)
# /wiki/File:Juno_prepared_for_rotation_test_stand.jpg
# /wiki/Juno_(spacecraft)
# /wiki/Polar_orbit
# #cite_note-NYT-20160705-84
# #cite_note-188
# #cite_note-189
# /wiki/Magnetosphere_of_Jupiter
# #cite_note-190
# /wiki/Jupiter%27s_North_Pole
# #cite_note-191
# #cite_note-sfnow20170221-192
# #cite_note-nasa20180606-193
# #cite_note-nasa20210108-194
# #cite_note-skytel20170221-195
# #cite_note-196
# /wiki/Jupiter_Icy_Moons_Orbiter
# #cite_note-197
# /wiki/European_Space_Agency
# /wiki/EJSM/Laplace
# /wiki/Jupiter_Europa_Orbiter
# /wiki/Jupiter_Ganymede_Orbiter
# #cite_note-198
# /wiki/Cosmic_Vision
# #cite_note-esaled-199
# /wiki/Jupiter_Icy_Moon_Explorer
# #cite_note-bbc-20230214-200
# /wiki/Europa_Clipper
# #cite_note-201
# /wiki/Chinese_National_Space_Administration
# /wiki/Tianwen-4
# /wiki/Callisto_(moon)
# #cite_note-202
# /wiki/Interstellar_Express
# #cite_note-203
# /wiki/Interstellar_Probe_(spacecraft)
# #cite_note-204
# /wiki/Moons_of_Jupiter
# /wiki/Timeline_of_discovery_of_Solar_System_planets_and_their_moons
# /wiki/Satellite_system_(astronomy)
# /wiki/Natural_satellite
# #cite_note-Hecht2023-205
# #cite_note-206
# #cite_note-SheppardMoons-8
# /wiki/Galilean_moons
# #cite_note-207
# /wiki/Galilean_moons
# /wiki/Laplace_resonance
# /wiki/Tidal_force
# /wiki/Tidal_circularization
# #cite_note-208
# /wiki/Orbital_eccentricity
# /wiki/Friction
# /wiki/Tidal_acceleration#Tidal_heating
# #cite_note-Eccen304-209
# /wiki/Io_(moon)#Volcanism
# #cite_note-Eccen304-209
# /wiki/Europa_(moon)#Surface_features
# #cite_note-210
# /wiki/Moon
# /wiki/Help:IPA/English
# /wiki/Io_(moon)
# /wiki/Help:IPA/English
# /wiki/Europa_(moon)
# /wiki/Help:IPA/English
# /wiki/Ganymede_(moon)
# /wiki/Help:IPA/English
# /wiki/Callisto_(moon)
# /wiki/Help:IPA/English
# /wiki/File:The_Galilean_satellites_(the_four_largest_moons_of_Jupiter).tif
# /wiki/Io_(moon)
# /wiki/Europa_(moon)
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Io_(moon)
# /wiki/Europa_(moon)
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Orbital_elements
# #cite_note-211
# /wiki/Themisto_(moon)
# /wiki/Valetudo_(moon)
# #cite_note-212
# /wiki/Regular_moon
# /wiki/Irregular_moons
# /wiki/Asteroid_capture
# #cite_note-213
# #cite_note-Nesvorný-214
# /wiki/Inner_satellites_of_Jupiter
# #cite_note-nasa_orbit_parameters-215
# /wiki/Galilean_moons
# #cite_note-216
# /wiki/Galileo_Galilei
# /wiki/Simon_Marius
# /wiki/Himalia_group
# /wiki/Retrograde_motion
# #cite_note-217
# /wiki/Carpo_(moon)
# #cite_note-SheppardMoons-8
# /wiki/Ananke_group
# /wiki/Retrograde_motion
# #cite_note-Nesvorný-214
# /wiki/Carme_group
# #cite_note-Nesvorný-214
# /wiki/Pasiphae_group
# #cite_note-218
# /wiki/Mercury_(planet)
# /wiki/Orbital_plane_(astronomy)
# /wiki/Celestial_equator
# /wiki/Kirkwood_gap
# /wiki/Asteroid_belt
# #cite_note-219
# /wiki/Late_Heavy_Bombardment
# #cite_note-220
# /wiki/Asteroid
# /wiki/Lagrangian_point
# /wiki/Trojan_asteroid
# /wiki/List_of_Trojan_asteroids_(Greek_camp)
# /wiki/List_of_Trojan_asteroids_(Trojan_camp)
# /wiki/Iliad
# /wiki/588_Achilles
# /wiki/Max_Wolf
# #cite_note-221
# /wiki/624_Hektor
# #cite_note-222
# /wiki/Semi-major_axis
# /wiki/List_of_periodic_comets
# /wiki/Kuiper_belt
# /wiki/Perturbation_(astronomy)
# #cite_note-223
# /wiki/Impact_events_on_Jupiter
# /wiki/File:Jupiter_showing_SL9_impact_sites.jpg
# /wiki/Comet_Shoemaker%E2%80%93Levy_9
# /wiki/Comet_Shoemaker%E2%80%93Levy_9#Jupiter's_role_in_protection_of_the_inner_Solar_System
# #cite_note-224
# /wiki/Gravity_well
# /wiki/List_of_Jupiter_events
# #cite_note-225
# /wiki/Asteroid
# /wiki/Comet
# #cite_note-HTUW-72
# #cite_note-HTUW-72
# /wiki/Accretion_(astrophysics)
# #cite_note-226
# /wiki/Kuiper_belt
# /wiki/Oort_cloud
# #cite_note-227
# /wiki/Comet_Shoemaker%E2%80%93Levy_9
# #cite_note-228
# #cite_note-229
# /wiki/Hubble_Space_Telescope
# #cite_note-230
# #cite_note-231
# #cite_note-232
# #cite_note-233
# /wiki/Giovanni_Domenico_Cassini
# #cite_note-234
# /wiki/Jupiter_in_fiction
# /wiki/Planets_in_astrology#Jupiter
# /wiki/File:Jupiter-bonatti.png
# /wiki/Guido_Bonatti
# #cite_note-235
# /wiki/Babylon
# /wiki/Marduk
# #cite_note-Rogers1998-236
# /wiki/Hammurabi
# #cite_note-237
# /wiki/Ecliptic
# /wiki/Constellation
# /wiki/Zodiac
# #cite_note-Rogers1998-236
# /wiki/Greek_mythology
# /wiki/Zeus
# /wiki/Greek_language
# #cite_note-238
# /wiki/Phaethon
# #cite_note-239
# #cite_note-240
# /wiki/Homer
# /wiki/Near_East
# /wiki/El_(deity)
# /wiki/Baal
# /wiki/Enlil
# #cite_note-241
# /wiki/Epinomis
# /wiki/Plato
# #cite_note-242
# /wiki/Jupiter_(god)
# /wiki/List_of_Roman_deities
# /wiki/Roman_mythology
# /wiki/Proto-Indo-European_language
# /wiki/Vocative
# /wiki/Dyeus
# #cite_note-etymologyonline-243
# #cite_note-244
# /wiki/Jyotisha
# /wiki/Brihaspati
# /wiki/Guru
# #cite_note-245
# #cite_note-246
# /wiki/Turkic_mythology
# #cite_note-247
# /wiki/Chinese_language
# /wiki/Pinyin
# /wiki/Five_elements_(Chinese_philosophy)
# #cite_note-248
# #cite_note-249
# #cite_note-250
# /wiki/Chinese_zodiac
# #cite_note-Homer-150
# /wiki/Outline_of_Jupiter
# /wiki/Eccentric_Jupiter
# /wiki/Hot_Jupiter
# /wiki/Super-Jupiter
# /wiki/Jovian%E2%80%93Plutonian_gravitational_effect
# /wiki/List_of_gravitationally_rounded_objects_of_the_Solar_System
# #cite_ref-caption_1-0
# /wiki/Atmosphere_of_Jupiter#Dynamics
# /wiki/Great_Red_Spot
# #cite_ref-1bar_11-0
# #cite_ref-1bar_11-1
# #cite_ref-1bar_11-2
# #cite_ref-1bar_11-3
# #cite_ref-1bar_11-4
# #cite_ref-1bar_11-5
# #cite_ref-1bar_b_13-0
# #cite_ref-29
# http://cbat.eps.harvard.edu/iauc/02800/02844.html
# http://adsabs.harvard.edu/cgi-bin/nph-abs_connect?db_key=AST&text=zenographic%20since%20at%20least%201966
# #cite_ref-50
# /wiki/Inverted_sugar_syrup
# /wiki/United_States_Pharmacopeia
# #cite_note-Swarbrick2013-49
# #cite_ref-169
# /wiki/Moons_of_Jupiter
# #cite_ref-2
# https://archive.org/details/oxfordenglishdic00_0
# /wiki/Oxford_English_Dictionary
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-19-861220-9
# #cite_ref-fact_3-0
# #cite_ref-fact_3-1
# #cite_ref-fact_3-2
# #cite_ref-fact_3-3
# #cite_ref-fact_3-4
# #cite_ref-fact_3-5
# #cite_ref-fact_3-6
# #cite_ref-fact_3-7
# https://nssdc.gsfc.nasa.gov/planetary/factsheet/jupiterfact.html
# /wiki/NASA
# https://web.archive.org/web/20191229035429/https://nssdc.gsfc.nasa.gov/planetary/factsheet/jupiterfact.html
# #cite_ref-planet_years_4-0
# #cite_ref-planet_years_4-1
# http://cseligman.com/text/sky/rotationvsday.htm
# https://web.archive.org/web/20180929010908/http://cseligman.com/text/sky/rotationvsday.htm
# #cite_ref-VSOP87_5-0
# #cite_ref-VSOP87_5-1
# #cite_ref-VSOP87_5-2
# #cite_ref-VSOP87_5-3
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/1994A&A...282..663S
# #cite_ref-Souami_Souchay_2012_6-0
# https://doi.org/10.1051%2F0004-6361%2F201219011
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2012A&A...543A.133S
# /wiki/Doi_(identifier)
# https://doi.org/10.1051%2F0004-6361%2F201219011
# #cite_ref-horizons-perihelion_7-0
# https://ssd.jpl.nasa.gov/horizons_batch.cgi?batch=1&COMMAND=%27599%27&START_TIME=%272023-01-01%27&STOP_TIME=%272023-01-31%27&STEP_SIZE=%273%20hours%27&QUANTITIES=%2719%27
# https://web.archive.org/web/20210907235300/https://ssd.jpl.nasa.gov/horizons_batch.cgi?batch=1&COMMAND=%27599%27&START_TIME=%272023-01-01%27&STOP_TIME=%272023-01-31%27&STEP_SIZE=%273%20hours%27&QUANTITIES=%2719%27
# #cite_ref-SheppardMoons_8-0
# #cite_ref-SheppardMoons_8-1
# #cite_ref-SheppardMoons_8-2
# /wiki/Doi_(identifier)
# https://doi.org/10.3847%2F2515-5172%2Facd766
# /wiki/Template:Cite_web
# /wiki/Help:CS1_errors#cite_web_url
# #cite_ref-Seidelmann_Archinal_A'hearn_et_al._2007_9-0
# https://doi.org/10.1007%2Fs10569-007-9072-y
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2007CeMDA..98..155S
# /wiki/Doi_(identifier)
# https://doi.org/10.1007%2Fs10569-007-9072-y
# /wiki/ISSN_(identifier)
# https://search.worldcat.org/issn/0923-2958
# #cite_ref-PS15_10-0
# https://books.google.com/books?id=stFpBgAAQBAJ&pg=PA250
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-521-85371-2
# #cite_ref-ssd-constants_12-0
# https://ssd.jpl.nasa.gov/?constants
# https://web.archive.org/web/20190321205811/https://ssd.jpl.nasa.gov/?constants
# #cite_ref-nasafact_14-0
# https://web.archive.org/web/20110905225941/http://solarsystem.nasa.gov/planets/profile.cfm?Object=Jupiter&Display=Facts
# https://solarsystem.nasa.gov/planets/profile.cfm?Object=Jupiter&Display=Facts
# #cite_ref-Ni2018_15-0
# https://doi.org/10.1051%2F0004-6361%2F201732183
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2018A&A...613A..32N
# /wiki/Doi_(identifier)
# https://doi.org/10.1051%2F0004-6361%2F201732183
# #cite_ref-iau2015_16-0
# #cite_ref-iau2015_16-1
# http://link.springer.com/10.1007/s10569-017-9805-5
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2018CeMDA.130...22A
# /wiki/Doi_(identifier)
# https://doi.org/10.1007%2Fs10569-017-9805-5
# /wiki/ISSN_(identifier)
# https://search.worldcat.org/issn/0923-2958
# #cite_ref-Li_et_al_17-0
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6137063
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2018NatCo...9.3709L
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2Fs41467-018-06107-2
# /wiki/PMC_(identifier)
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6137063
# /wiki/PMID_(identifier)
# https://pubmed.ncbi.nlm.nih.gov/30213944
# #cite_ref-Mallama_et_al_18-0
# /wiki/ArXiv_(identifier)
# https://arxiv.org/abs/1609.05048
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2017Icar..282...19M
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2Fj.icarus.2016.09.023
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:119307693
# #cite_ref-Mallama_and_Hilton_19-0
# #cite_ref-Mallama_and_Hilton_19-1
# #cite_ref-Mallama_and_Hilton_19-2
# #cite_ref-Mallama_and_Hilton_19-3
# /wiki/ArXiv_(identifier)
# https://arxiv.org/abs/1808.01973
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2018A&C....25...10M
# /wiki/Doi_(identifier)
# https://doi.org/10.1016%2Fj.ascom.2018.08.002
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:69912809
# #cite_ref-IMCCE_20-0
# https://promenade.imcce.fr/en/pages5/572.html
# https://web.archive.org/web/20230724225002/https://promenade.imcce.fr/en/pages5/572.html
# #cite_ref-21
# /wiki/ArXiv_(identifier)
# https://arxiv.org/abs/1508.04795
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2015ApJ...810..122B
# /wiki/Doi_(identifier)
# https://doi.org/10.1088%2F0004-637X%2F810%2F2%2F122
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:55592285
# #cite_ref-22
# #cite_ref-23
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2015msls.book.....A
# /wiki/Doi_(identifier)
# https://doi.org/10.1007%2F978-1-4614-7067-0
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-4614-7066-3
# #cite_ref-24
# https://www.iau.org/public/themes/naming/
# https://web.archive.org/web/20131031154417/https://www.iau.org/public/themes/naming/
# #cite_ref-jones-1999_25-0
# https://books.google.com/books?id=8MokzymQ43IC
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0
# /wiki/S2CID_(identifier)
# https://api.semanticscholar.org/CorpusID:199100280
# #cite_ref-dangelo_marzari_2012_41-0
# /wiki/ArXiv_(identifier)
# https://arxiv.org/abs/1207.2737
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2012ApJ...757...50D
# /wiki/Doi_(identifier)
# ...
# /wiki/List_of_Jupiter_trojans_(Trojan_camp)
# /wiki/Impact_events_on_Jupiter
# /wiki/Comet_Shoemaker%E2%80%93Levy_9
# /wiki/2009_Jupiter_impact_event
# /wiki/2010_Jupiter_impact_event
# /wiki/2016_Jupiter_impact_event
# /wiki/Exploration_of_Jupiter
# /wiki/Juno_(spacecraft)
# /wiki/Cassini%E2%80%93Huygens
# /wiki/Galileo_project
# /wiki/Galileo_(spacecraft)
# /wiki/New_Horizons
# /wiki/Pioneer_program
# /wiki/Pioneer_10
# /wiki/Pioneer_11
# /wiki/Ulysses_(spacecraft)
# /wiki/Voyager_program
# /wiki/Voyager_1
# /wiki/Voyager_2
# /wiki/Jupiter_Icy_Moons_Explorer
# /wiki/Europa_Clipper
# /wiki/Tianwen-4
# /wiki/Solar_Polar_Orbit_Observatory
# /wiki/Laplace-P
# /wiki/Shensuo_(spacecraft)
# /wiki/Io_Volcano_Observer
# /wiki/SMARA_(spacecraft)
# /wiki/Enceladus_Orbilander
# /wiki/Jupiter_in_fiction
# /wiki/Jupiter_(mythology)
# /wiki/Category:Jupiter
# /wiki/Portal:Solar_System
# /wiki/Template:Moons_of_Jupiter
# /wiki/Template_talk:Moons_of_Jupiter
# /wiki/Special:EditPage/Template:Moons_of_Jupiter
# /wiki/Moons_of_Jupiter
# /wiki/Metis_(moon)
# /wiki/Adrastea_(moon)
# /wiki/Amalthea_(moon)
# /wiki/Thebe_(moon)
# /wiki/Galilean_moons
# /wiki/Io_(moon)
# /wiki/Europa_(moon)
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Themisto_(moon)
# /wiki/Himalia_group
# /wiki/Leda_(moon)
# /wiki/Ersa_(moon)
# /wiki/S/2018_J_2
# /wiki/Himalia_(moon)
# /wiki/Pandia_(moon)
# /wiki/Lysithea_(moon)
# /wiki/Elara_(moon)
# /wiki/S/2011_J_3
# /wiki/Dia_(moon)
# /wiki/S/2018_J_4
# /wiki/Carpo_(moon)
# /wiki/Valetudo_(moon)
# /wiki/Ananke_group
# /wiki/Euporie_(moon)
# /wiki/Jupiter_LV
# /wiki/Eupheme_(moon)
# /wiki/S/2021_J_3
# /wiki/Jupiter_LII
# /wiki/Jupiter_LIV
# /wiki/Mneme_(moon)
# /wiki/Euanthe_(moon)
# /wiki/S/2003_J_16
# /wiki/Harpalyke_(moon)
# /wiki/Orthosie_(moon)
# /wiki/S/2022_J_3
# /wiki/Helike_(moon)
# /wiki/S/2021_J_2
# /wiki/Praxidike_(moon)
# /wiki/Jupiter_LXIV
# /wiki/S/2021_J_1
# /wiki/S/2003_J_12
# /wiki/Jupiter_LXVIII
# /wiki/Thelxinoe_(moon)
# /wiki/Thyone_(moon)
# /wiki/S/2003_J_2
# /wiki/Ananke_(moon)
# /wiki/Iocaste_(moon)
# /wiki/Hermippe_(moon)
# /wiki/Jupiter_LXX
# /wiki/Carme_group
# /wiki/S/2022_J_1
# /wiki/S/2022_J_2
# /wiki/S/2016_J_3
# /wiki/Pasithee_(moon)
# /wiki/Jupiter_LXIX
# /wiki/S/2021_J_6
# /wiki/S/2003_J_24
# /wiki/Chaldene
# /wiki/Jupiter_LXIII
# /wiki/Isonoe_(moon)
# /wiki/S/2021_J_4
# /wiki/Kallichore_(moon)
# /wiki/Erinome
# /wiki/Kale_(moon)
# /wiki/Eirene_(moon)
# /wiki/Aitne_(moon)
# /wiki/Eukelade
# /wiki/Arche_(moon)
# /wiki/Taygete_(moon)
# /wiki/Jupiter_LXXII
# /wiki/Carme_(moon)
# /wiki/Herse_(moon)
# /wiki/Jupiter_LXI
# /wiki/Jupiter_LI
# /wiki/S/2003_J_9
# /wiki/Jupiter_LXVI
# /wiki/Kalyke
# /wiki/S/2018_J_3
# /wiki/S/2021_J_5
# /wiki/S/2003_J_10
# /wiki/Pasiphae_group
# /wiki/Philophrosyne_(moon)
# /wiki/Eurydome_(moon)
# /wiki/Jupiter_LVI
# /wiki/S/2003_J_4
# /wiki/S/2016_J_4
# /wiki/Jupiter_LXVII
# /wiki/Hegemone_(moon)
# /wiki/Pasiphae_(moon)
# /wiki/Sponde
# /wiki/Megaclite
# /wiki/Cyllene_(moon)
# /wiki/Sinope_(moon)
# /wiki/Jupiter_LIX
# /wiki/Aoede_(moon)
# /wiki/Autonoe_(moon)
# /wiki/Callirrhoe_(moon)
# /wiki/S/2003_J_23
# /wiki/Kore_(moon)
# /wiki/Rings_of_Jupiter
# /wiki/Jupiter%27s_moons_in_fiction
# /wiki/Category:Moons_of_Jupiter
# /wiki/Template:Jupiter_spacecraft
# /wiki/Template_talk:Jupiter_spacecraft
# /wiki/Special:EditPage/Template:Jupiter_spacecraft
# /wiki/Exploration_of_Jupiter
# None
# /wiki/Pioneer_program
# /wiki/Pioneer_10
# /wiki/Pioneer_11
# /wiki/Voyager_program
# /wiki/Voyager_1
# /wiki/Voyager_2
# /wiki/Ulysses_(spacecraft)
# /wiki/Cassini%E2%80%93Huygens
# /wiki/New_Horizons
# /wiki/File:Portrait_of_Jupiter_from_Cassini.jpg
# /wiki/Galileo_project
# /wiki/Juno_(spacecraft)
# /wiki/Galileo_Probe
# /wiki/Jupiter_Icy_Moons_Explorer
# /wiki/Europa_Clipper
# /wiki/Tianwen-4
# /wiki/Solar_Polar_Orbit_Observatory
# /wiki/Shensuo_(spacecraft)
# /wiki/Europa_Lander
# /wiki/Interstellar_Probe_(spacecraft)
# /wiki/Argo_(NASA_spacecraft)
# /wiki/Europa_Jupiter_System_Mission_%E2%80%93_Laplace
# /wiki/Jupiter_Europa_Orbiter
# /wiki/Jupiter_Ganymede_Orbiter
# /wiki/Jupiter_Magnetospheric_Orbiter
# /wiki/Europa_Orbiter
# /wiki/Flyby_of_Io_with_Repeat_Encounters
# /wiki/Innovative_Interstellar_Explorer
# /wiki/Io_Volcano_Observer
# /wiki/Jovian_Europa_Orbiter
# /wiki/Jupiter_Icy_Moons_Orbiter
# /wiki/Laplace-P
# /wiki/New_Horizons_2
# /wiki/OKEANOS
# /wiki/Pioneer_H
# /wiki/SMARA_(spacecraft)
# /wiki/Trident_(spacecraft)
# /wiki/Tsiolkovsky_mission
# /wiki/Exploration_of_Jupiter
# /wiki/Atmosphere_of_Jupiter
# /wiki/Magnetosphere_of_Jupiter
# /wiki/Moons_of_Jupiter
# /wiki/Io_(moon)
# /wiki/Exploration_of_Io
# /wiki/Europa_(moon)
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Rings_of_Jupiter
# /wiki/Deep_Space_Network
# /wiki/List_of_missions_to_the_outer_planets
# /wiki/Colonization_of_the_outer_Solar_System
# /wiki/Gravity_assist
# /wiki/Template:Solar_System
# /wiki/Template_talk:Solar_System
# /wiki/Special:EditPage/Template:Solar_System
# /wiki/Solar_System
# /wiki/Sun
# /wiki/Mercury_(planet)
# /wiki/Venus
# /wiki/Earth
# /wiki/Mars
# /wiki/Ceres_(dwarf_planet)
# None
# /wiki/Saturn
# /wiki/Uranus
# /wiki/Neptune
# /wiki/Orcus_(dwarf_planet)
# /wiki/Pluto
# /wiki/Haumea
# /wiki/Quaoar
# /wiki/Makemake
# /wiki/Gonggong_(dwarf_planet)
# /wiki/Eris_(dwarf_planet)
# /wiki/Sedna_(dwarf_planet)
# /wiki/Planet
# /wiki/Dwarf_planet
# /wiki/Minor_planet
# /wiki/Terrestrial_planet
# /wiki/Mercury_(planet)
# /wiki/Venus
# /wiki/Earth
# /wiki/Mars
# /wiki/Giant_planet
# /wiki/Gas_giant
# None
# /wiki/Saturn
# /wiki/Ice_giant
# /wiki/Uranus
# /wiki/Neptune
# /wiki/Dwarf_planet
# /wiki/Ceres_(dwarf_planet)
# /wiki/Orcus_(dwarf_planet)
# /wiki/Pluto
# /wiki/Haumea
# /wiki/Quaoar
# /wiki/Makemake
# /wiki/Gonggong_(dwarf_planet)
# /wiki/Eris_(dwarf_planet)
# /wiki/Sedna_(dwarf_planet)
# /wiki/Minor_planet
# /wiki/120347_Salacia
# /wiki/20000_Varuna
# /wiki/28978_Ixion
# /wiki/List_of_minor_planets
# /wiki/Natural_satellite
# /wiki/Moon
# /wiki/Claimed_moons_of_Earth
# /wiki/Moons_of_Mars
# /wiki/Phobos_(moon)
# /wiki/Deimos_(moon)
# /wiki/Moons_of_Jupiter
# /wiki/Ganymede_(moon)
# /wiki/Callisto_(moon)
# /wiki/Io_(moon)
# /wiki/Europa_(moon)
# /wiki/Moons_of_Jupiter#List
# /wiki/Moons_of_Saturn
# /wiki/Titan_(moon)
# /wiki/Rhea_(moon)
# /wiki/Iapetus_(moon)
# /wiki/Dione_(moon)
# /wiki/Tethys_(moon)
# /wiki/Enceladus
# /wiki/Mimas
# /wiki/Hyperion_(moon)
# /wiki/Phoebe_(moon)
# /wiki/Moons_of_Saturn#List
# /wiki/Moons_of_Uranus
# /wiki/Titania_(moon)
# /wiki/Oberon_(moon)
# /wiki/Umbriel
# /wiki/Ariel_(moon)
# /wiki/Miranda_(moon)
# /wiki/Moons_of_Uranus#List
# /wiki/Moons_of_Neptune
# /wiki/Triton_(moon)
# /wiki/Proteus_(moon)
# /wiki/Nereid_(moon)
# /wiki/Moons_of_Neptune#List
# /wiki/Moons_of_Pluto
# /wiki/Charon_(moon)
# /wiki/Nix_(moon)
# /wiki/Hydra_(moon)
# /wiki/Kerberos_(moon)
# /wiki/Styx_(moon)
# /wiki/Orcus_(dwarf_planet)
# /wiki/Vanth_(moon)
# /wiki/Moons_of_Haumea
# /wiki/Hi%CA%BBiaka_(moon)
# /wiki/Namaka_(moon)
# /wiki/Quaoar
# /wiki/Weywot
# /wiki/Makemake
# /wiki/S/2015_(136472)_1
# /wiki/Gonggong_(dwarf_planet)
# /wiki/Xiangliu_(moon)
# /wiki/Eris_(dwarf_planet)
# /wiki/Dysnomia_(moon)
# /wiki/Formation_and_evolution_of_the_Solar_System
# /wiki/History_of_Solar_System_formation_and_evolution_hypotheses
# /wiki/Star_formation
# /wiki/Accretion_(astrophysics)
# /wiki/Accretion_disk
# /wiki/Accretion_disk#Excretion_disk
# /wiki/History_of_Solar_System_formation_and_evolution_hypotheses#Capture_hypothesis
# /wiki/Capture_of_Triton
# /wiki/Circumplanetary_disk
# /wiki/Circumstellar_disc
# /wiki/Circumstellar_envelope
# /wiki/Coatlicue_(star)
# /wiki/Co-orbital_configuration
# /wiki/Co-orbital_configuration#Trojan_moons
# /wiki/Cosmic_dust
# /wiki/Debris_disk
# /wiki/Detached_object
# /wiki/Ice_giant#Disk_instability
# /wiki/Exoplanetary_Circumstellar_Environments_and_Disk_Explorer
# /wiki/Exozodiacal_dust
# /wiki/Extraterrestrial_materials
# /wiki/Extraterrestrial_sample_curation
# /wiki/Sample-return_mission
# /wiki/Frost_line_(astrophysics)
# /wiki/Giant-impact_hypothesis
# /wiki/Grand_tack_hypothesis
# /wiki/Gravitational_collapse
# /wiki/Hills_cloud
# /wiki/Hill_sphere
# /wiki/Interplanetary_dust_cloud
# /wiki/Interplanetary_medium
# /wiki/Interstellar_cloud
# /wiki/Interstellar_medium
# /wiki/Outer_space#Interstellar_space
# /wiki/Kordylewski_cloud
# /wiki/Kuiper_belt
# /wiki/Kuiper_cliff
# /wiki/Late_Heavy_Bombardment
# /wiki/Molecular_cloud
# /wiki/Nebular_hypothesis
# /wiki/Nice_model
# /wiki/Nice_2_model
# /wiki/Five-planet_Nice_model
# /wiki/Oort_cloud
# /wiki/Outer_space
# /wiki/Planet
# /wiki/Disrupted_planet
# /wiki/Planetary_migration
# /wiki/Planetary_system
# /wiki/Planetesimal
# /wiki/Nebular_hypothesis#Formation_of_planets
# /wiki/Stellar_collision#Formation_of_planets
# /wiki/Protoplanetary_disk
# /wiki/Ring_system
# /wiki/Roche_limit
# /wiki/Roche_limit#Roche_limit,_Hill_sphere_and_radius_of_the_planet
# /wiki/Rubble_pile
# /wiki/Scattered_disc
# /wiki/Ring_system
# /wiki/Rings_of_Earth
# /wiki/Rings_of_Jupiter
# /wiki/Rings_of_Saturn
# /wiki/Rings_of_Rhea
# /wiki/Rings_of_Chariklo
# /wiki/2060_Chiron#Rings
# /wiki/Rings_of_Uranus
# /wiki/Rings_of_Neptune
# /wiki/Haumea#Ring
# /wiki/Quaoar#Rings
# /wiki/List_of_hypothetical_Solar_System_objects
# /wiki/Claimed_moons_of_Earth#Other_claims
# /wiki/Chiron_(hypothetical_moon)
# /wiki/Coatlicue_(star)
# /wiki/Counter-Earth
# /wiki/Chrysalis_(hypothetical_moon)
# /wiki/Fifth_Giant
# /wiki/Hyperion_(hypothetical_planet)
# /wiki/Planetary_objects_proposed_in_religion,_astrology,_ufology_and_pseudoscience#Lilith
# /wiki/Hypothetical_moon_of_Mercury
# /wiki/Neith_(hypothetical_moon)
# /wiki/Nemesis_(hypothetical_star)
# /wiki/Nibiru_cataclysm
# /wiki/Claimed_moons_of_Earth#Petit's_moon
# /wiki/Phaeton_(hypothetical_planet)
# /wiki/Planet_Nine
# /wiki/Planets_beyond_Neptune#Kuiper_cliff_and_"Planet_Ten"
# /wiki/Planet_V
# /wiki/Planets_beyond_Neptune#Planet_X
# /wiki/Subsatellite
# /wiki/Synestia#Giant-impact_hypothesis
# /wiki/Theia_(planet)
# /wiki/Themis_(hypothetical_moon)
# /wiki/Tyche_(hypothetical_planet)
# /wiki/Vulcan_(hypothetical_planet)
# /wiki/Vulcanoid
# /wiki/Claimed_moons_of_Earth#Waltemath's_moons
# /wiki/Space_exploration
# /wiki/Outline_of_space_exploration
# /wiki/Space_colonization
# /wiki/Discovery_and_exploration_of_the_Solar_System
# /wiki/Astronomy
# /wiki/Historical_models_of_the_Solar_System
# /wiki/Timeline_of_discovery_of_Solar_System_planets_and_their_moons
# /wiki/Space_probe
# /wiki/Timeline_of_Solar_System_exploration
# /wiki/List_of_Solar_System_probes
# /wiki/Human_spaceflight
# /wiki/Space_station
# /wiki/List_of_crewed_spacecraft
# /wiki/Human_spaceflight_programs
# /wiki/Exploration_of_Mercury
# /wiki/Observations_and_explorations_of_Venus
# /wiki/Exploration_of_the_Moon
# /wiki/Lunar_resources
# /wiki/Exploration_of_Mars
# /wiki/Ceres_(dwarf_planet)#Exploration
# /wiki/Asteroid#Exploration
# /wiki/Asteroid_mining
# /wiki/List_of_missions_to_comets
# /wiki/Exploration_of_Jupiter
# /wiki/Exploration_of_Saturn
# /wiki/Exploration_of_Uranus
# /wiki/Exploration_of_Neptune
# /wiki/Exploration_of_Pluto
# /wiki/Deep_space_exploration
# /wiki/Small_Solar_System_body
# /wiki/Comet
# /wiki/Damocloid
# /wiki/Meteoroid
# /wiki/Minor_planet
# /wiki/Meanings_of_minor-planet_names
# /wiki/Minor-planet_moon
# /wiki/Planetesimal
# /wiki/List_of_Mercury-crossing_minor_planets
# /wiki/List_of_Venus-crossing_minor_planets
# /wiki/List_of_Earth-crossing_asteroids
# /wiki/List_of_Mars-crossing_minor_planets
# /wiki/List_of_Jupiter-crossing_minor_planets
# /wiki/List_of_Saturn-crossing_minor_planets
# /wiki/List_of_Uranus-crossing_minor_planets
# /wiki/List_of_Neptune-crossing_minor_planets
# /wiki/Trojan_(celestial_body)
# /wiki/2013_ND15
# /wiki/Earth_trojan
# /wiki/Mars_trojan
# /wiki/Jupiter_trojan
# /wiki/List_of_Jupiter_trojans_(Trojan_camp)
# /wiki/List_of_Jupiter_trojans_(Greek_camp)
# /wiki/2019_UO14
# /wiki/Uranus_trojans
# /wiki/Neptune_trojan
# /wiki/Near-Earth_object
# /wiki/Near-Earth_object#Near-Earth_asteroids
# /wiki/Asteroid_belt
# /wiki/Asteroid
# /wiki/Ceres_(dwarf_planet)
# /wiki/4_Vesta
# /wiki/2_Pallas
# /wiki/10_Hygiea
# /wiki/Active_asteroid
# /wiki/List_of_minor_planets
# /wiki/Asteroid_family
# /wiki/Potentially_hazardous_object
# /wiki/List_of_exceptional_asteroids
# /wiki/Kirkwood_gap
# /wiki/Centaur_(small_Solar_System_body)
# /wiki/Trans-Neptunian_object
# /wiki/Kuiper_belt
# /wiki/Classical_Kuiper_belt_object
# /wiki/Plutino
# /wiki/Detached_object
# /wiki/Sednoid
# /wiki/Scattered_disc
# /wiki/Hills_cloud
# /wiki/Oort_cloud
# /wiki/Lists_of_comets
# /wiki/List_of_possible_dwarf_planets
# /wiki/List_of_gravitationally_rounded_objects_of_the_Solar_System
# /wiki/List_of_minor_planets
# /wiki/List_of_natural_satellites
# /wiki/Solar_System_model
# /wiki/List_of_Solar_System_objects
# /wiki/List_of_Solar_System_objects_by_size
# /wiki/Timeline_of_discovery_of_Solar_System_planets_and_their_moons
# /wiki/List_of_interstellar_and_circumstellar_molecules
# /wiki/Double_planet
# /wiki/Lagrange_point
# /wiki/Moonlet
# /wiki/Syzygy_(astronomy)
# /wiki/Tidal_locking
# /wiki/Outline_of_the_Solar_System
# /wiki/Portal:Solar_System
# /wiki/Portal:Astronomy
# /wiki/Portal:Earth_sciences
# /wiki/Solar_System
# /wiki/Local_Interstellar_Cloud
# /wiki/Local_Bubble
# /wiki/Gould_Belt
# /wiki/Orion_Arm
# /wiki/Milky_Way
# /wiki/Satellite_galaxies_of_the_Milky_Way
# /wiki/Local_Group
# /wiki/Local_Sheet
# /wiki/Virgo_Supercluster
# /wiki/Laniakea_Supercluster
# /wiki/Local_Hole
# /wiki/Observable_universe
# /wiki/Universe
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q319#identifiers
# https://viaf.org/viaf/316741895
# http://id.worldcat.org/fast/1244812/
# https://d-nb.info/gnd/4162926-7
# https://id.loc.gov/authorities/sh85071063
# https://catalogue.bnf.fr/ark:/12148/cb121083440
# https://data.bnf.fr/ark:/12148/cb121083440
# https://id.ndl.go.jp/auth/ndlna/00567795
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=ph117662&CON_LNG=ENG
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX453719
# http://katalog.nsk.hr/F/?func=direct&doc_number=000398127&local_base=nsk10
# https://www.nli.org.il/en/authorities/987007538525205171
# https://www.idref.fr/029460913
# https://catalog.archives.gov/id/10046639
# /wiki/Wikipedia:Contents/Portals
# /wiki/File:He1523a.jpg
# /wiki/Portal:Stars
# /wiki/Portal:Spaceflight
# /wiki/Portal:Outer_space
# https://en.wikipedia.org/w/index.php?title=Jupiter&oldid=1280390846
# /wiki/Help:Category
# /wiki/Category:Jupiter
# /wiki/Category:Astronomical_objects_known_since_antiquity
# /wiki/Category:Gas_giants
# /wiki/Category:Outer_planets
# /wiki/Category:Solar_System
# /wiki/Category:Pages_using_the_Phonos_extension
# /wiki/Category:CS1_errors:_requires_URL
# /wiki/Category:CS1:_long_volume_value
# /wiki/Category:Wikipedia_articles_needing_page_number_citations_from_May_2015
# /wiki/Category:All_articles_with_dead_external_links
# /wiki/Category:Articles_with_dead_external_links_from_July_2022
# /wiki/Category:CS1_Turkish-language_sources_(tr)
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Good_articles
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Use_Oxford_spelling_from_November_2024
# /wiki/Category:Use_mdy_dates_from_November_2024
# /wiki/Category:Pages_including_recorded_pronunciations
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2023
# /wiki/Category:All_articles_containing_potentially_dated_statements
# /wiki/Category:Pages_using_multiple_image_with_manual_scaled_images
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2015
# /wiki/Category:Pages_using_multiple_image_with_auto_scaled_images
# /wiki/Category:Articles_containing_Chinese-language_text
# /wiki/Category:Articles_containing_Ancient_Greek_(to_1453)-language_text
# /wiki/Category:Pages_using_Sister_project_links_with_default_search
# /wiki/Category:Articles_containing_video_clips
# /wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_4.0_International_License
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# https://wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Universal_Code_of_Conduct
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Jupiter&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/
# #
# #
# #
# #
# #
# #
# #
# #

# %% [markdown]
# ## Let us move into scraping images from the web

# %% [markdown]
# For purpose of this example, we will be using google website for scraping data
#
# Let us look into the images used in the google homepage

# %%
htmldata = urlopen('https://www.walmart.com/search?')
soup = BeautifulSoup(htmldata, 'html.parser')
images = soup.find_all('img')

for item in images:
    print(item['src'])

# %% [markdown]
# ##### Let us now look using google for downloading images

# %% [markdown]
# The working of the code here will be simple
# We put in the required link in which the crawler scraps for data
#
# After finding the required data, we use shutil to download the required amount of images we need

# %% [markdown]
# Here we see, the code asks for what type of image we need
#
# So it gives the end-user an option to select any thing in the world to create a dataset

# %% [markdown]
# After selecting, the code asks for the number of images we want

# %% [markdown]
# Again, any number you want!
#
# Go ahead and enter it!

# %%
import requests

# Replace with your API key
API_KEY = 'AIzaSyDDlrMTXE6vglEf6tv0SkBv-LQxnMUGkhg'

def get_video_thumbnail(video_id):
    # API URL
    url = f'https://www.googleapis.com/youtube/v3/videos?id={video_id}&key={API_KEY}&part=snippet'

    # Send request to YouTube API
    response = requests.get(url)

    # Check if response is OK
    if response.status_code == 200:
        video_data = response.json()

        if 'items' in video_data and len(video_data['items']) > 0:
            thumbnail_url = video_data['items'][0]['snippet']['thumbnails']['high']['url']
            print(f"Thumbnail URL: {thumbnail_url}")
            return thumbnail_url
        else:
            print("No video found.")
    else:
        print(f"Error: {response.status_code}")

def download_image(image_url, filename):
    # Download the image and save it
    response = requests.get(image_url)
    with open(filename, 'wb') as f:
        f.write(response.content)
    print(f"Downloaded image: {filename}")

# Example: Replace with any YouTube video ID
video_id = 'dQw4w9WgXcQ'  # Replace with the video ID you want to fetch the thumbnail for
thumbnail_url = get_video_thumbnail(video_id)

if thumbnail_url:
    # Download the image to your local machine
    download_image(thumbnail_url, f'{video_id}_thumbnail.jpg')
# Out:
# Thumbnail URL: https://i.ytimg.com/vi/dQw4w9WgXcQ/hqdefault.jpg
# Downloaded image: dQw4w9WgXcQ_thumbnail.jpg
